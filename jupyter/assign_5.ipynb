# %%
n = 20
while n> 2:
    if n % 2==0:
        print(n)
    n=n-1
print(n)
# Out:
# 20
# 18
# 16
# 14
# 12
# 10
# 8
# 6
# 4
# 2

# %%
user = int(input(" guss a number:"))
if user ==7:
    print("correct")
else:
    print("incorrect")"
# Out:
# correct
